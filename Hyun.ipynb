# %% [markdown]
# <a href="https://colab.research.google.com/github/hcpy/Local-GH-Data-for-Python-Project/blob/main/Hyun.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#5b OH with Prof Lee. 
import os
from google.colab import drive
drive.mount('/content/drive/')
os.chdir("/content/drive/MyDrive/FAES_BIOF309/temp")


import pandas as pd
import seaborn as sns
import matplotlib as plt
import numpy as np
#pandas call my data and call it lungsheet
lungsheet = pd.read_csv("/content/drive/MyDrive/FAES_BIOF309/Project_data/TrimmedDataSet.csv.csv", header=1)
lungsheet
sns.relplot(lungsheet['age'],lungsheet['Cigarette_total'])
#OH
# Out:
# Mounted at /content/drive/
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
